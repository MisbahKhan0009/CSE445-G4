# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.6.1-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\mkhan\documents\academic\cse445\cse445-g4\cse445\lib\site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\mkhan\documents\academic\cse445\cse445-g4\cse445\lib\site-packages (from scikit-learn) (1.15.2)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.6.1-cp312-cp312-win_amd64.whl (11.1 MB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 threadpoolctl-3.5.0
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Cell 1: Imports
import os
import numpy as np
from PIL import Image
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
import matplotlib.pyplot as plt

# %%
# Cell 2: Load Images Function
def load_images(hr_path, lr_path):
    hr_images = []
    lr_images = []
    
    for i in range(1, 101):  # Assuming 100 images
        hr_file = os.path.join(hr_path, f'HR{i:03d}.jpg')
        lr_file = os.path.join(lr_path, f'LR{i:03d}.jpg')
        
        if os.path.exists(hr_file) and os.path.exists(lr_file):
            hr_img = np.array(Image.open(hr_file).resize((256, 256))) / 255.0
            lr_img = np.array(Image.open(lr_file).resize((64, 64))) / 255.0
            
            hr_images.append(hr_img)
            lr_images.append(lr_img)
    
    return np.array(hr_images), np.array(lr_images)

# Load the images
hr_path = '../data/highRes'
lr_path = '../data/lowRes'
hr_images, lr_images = load_images(hr_path, lr_path)

# Split dataset
lr_train, lr_test, hr_train, hr_test = train_test_split(
    lr_images, hr_images, test_size=0.2, random_state=42
)

print(f"Training samples: {len(lr_train)}")
print(f"Testing samples: {len(lr_test)}")
# Out:
# Training samples: 80
# Testing samples: 20

# %%
# Cell 3: Build Model
def build_sr_model():
    model = models.Sequential([
        layers.Input(shape=(64, 64, 3)),
        layers.Conv2D(64, 9, padding='same', activation='relu'),
        layers.Conv2D(32, 5, padding='same', activation='relu'),
        layers.Conv2D(32, 5, padding='same', activation='relu'),
        layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation='relu'),
        layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation='relu'),
        layers.Conv2D(3, 5, padding='same', activation='sigmoid')
    ])
    return model

# Create and compile model
model = build_sr_model()
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 64, 64, 64)          │          15,616 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 32)          │          51,232 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 64, 64, 32)          │          25,632 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose (Conv2DTranspose)   │ (None, 128, 128, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_1 (Conv2DTranspose) │ (None, 256, 256, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 256, 256, 3)         │           2,403 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 113,379 (442.89 KB)
#  Trainable params: 113,379 (442.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Cell 4: Train Model
history = model.fit(
    lr_train, hr_train,
    epochs=50,
    batch_size=8,
    validation_data=(lr_test, hr_test),
    verbose=1
)

# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('Model MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - loss: 0.0900 - mae: 0.2640 - val_loss: 0.0780 - val_mae: 0.2398
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - loss: 0.0877 - mae: 0.2593 - val_loss: 0.0711 - val_mae: 0.2264
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - loss: 0.0811 - mae: 0.2470 - val_loss: 0.0609 - val_mae: 0.2103
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - loss: 0.0703 - mae: 0.2269 - val_loss: 0.0468 - val_mae: 0.1803
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - loss: 0.0503 - mae: 0.1897 - val_loss: 0.0351 - val_mae: 0.1446
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step - loss: 0.0345 - mae: 0.1493 - val_loss: 0.0340 - val_mae: 0.1479
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 166ms/step - loss: 0.0319 - mae: 0.1412 - val_loss: 0.0256 - val_mae: 0.1213
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - loss: 0.0238 - mae: 0.1179 - val_loss: 0.0223 - val_mae: 0.1119
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step - loss: 0.0207 - mae: 0.1074 - val_loss: 0.0199 - val_mae: 0.1049
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - loss: 0.0187 - mae: 0.1003 - val_loss: 0.0178 - val_mae: 0.0960
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - loss: 0.0148 - mae: 0.0890 - val_loss: 0.0167 - val_mae: 0.0926
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step - loss: 0.0164 - mae: 0.0925 - val_loss: 0.0171 - val_mae: 0.0952
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - loss: 0.0172 - mae: 0.0966 - val_loss: 0.0203 - val_mae: 0.1047
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 166ms/step - loss: 0.0168 - mae: 0.0969 - val_loss: 0.0182 - val_mae: 0.0983
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - loss: 0.0148 - mae: 0.0863 - val_loss: 0.0157 - val_mae: 0.0887
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - loss: 0.0134 - mae: 0.0836 - val_loss: 0.0148 - val_mae: 0.0841
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - loss: 0.0127 - mae: 0.0790 - val_loss: 0.0151 - val_mae: 0.0839
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 173ms/step - loss: 0.0117 - mae: 0.0750 - val_loss: 0.0148 - val_mae: 0.0848
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - loss: 0.0112 - mae: 0.0738 - val_loss: 0.0143 - val_mae: 0.0816
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - loss: 0.0115 - mae: 0.0742 - val_loss: 0.0138 - val_mae: 0.0797
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - loss: 0.0101 - mae: 0.0697 - val_loss: 0.0136 - val_mae: 0.0791
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - loss: 0.0108 - mae: 0.0721 - val_loss: 0.0134 - val_mae: 0.0785
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 166ms/step - loss: 0.0108 - mae: 0.0713 - val_loss: 0.0138 - val_mae: 0.0802
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - loss: 0.0107 - mae: 0.0720 - val_loss: 0.0130 - val_mae: 0.0767
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - loss: 0.0107 - mae: 0.0706 - val_loss: 0.0132 - val_mae: 0.0785
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - loss: 0.0107 - mae: 0.0711 - val_loss: 0.0129 - val_mae: 0.0775
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - loss: 0.0096 - mae: 0.0677 - val_loss: 0.0126 - val_mae: 0.0764
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - loss: 0.0098 - mae: 0.0686 - val_loss: 0.0127 - val_mae: 0.0755
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - loss: 0.0098 - mae: 0.0675 - val_loss: 0.0124 - val_mae: 0.0760
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - loss: 0.0098 - mae: 0.0680 - val_loss: 0.0121 - val_mae: 0.0738
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - loss: 0.0088 - mae: 0.0643 - val_loss: 0.0119 - val_mae: 0.0735
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 166ms/step - loss: 0.0092 - mae: 0.0653 - val_loss: 0.0119 - val_mae: 0.0737
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step - loss: 0.0089 - mae: 0.0643 - val_loss: 0.0118 - val_mae: 0.0742
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 173ms/step - loss: 0.0089 - mae: 0.0648 - val_loss: 0.0113 - val_mae: 0.0707
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 168ms/step - loss: 0.0090 - mae: 0.0652 - val_loss: 0.0112 - val_mae: 0.0708
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - loss: 0.0090 - mae: 0.0657 - val_loss: 0.0111 - val_mae: 0.0701
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - loss: 0.0085 - mae: 0.0634 - val_loss: 0.0111 - val_mae: 0.0699
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step - loss: 0.0093 - mae: 0.0670 - val_loss: 0.0176 - val_mae: 0.0940
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - loss: 0.0126 - mae: 0.0801 - val_loss: 0.0129 - val_mae: 0.0787
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - loss: 0.0107 - mae: 0.0740 - val_loss: 0.0119 - val_mae: 0.0747
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 166ms/step - loss: 0.0097 - mae: 0.0684 - val_loss: 0.0131 - val_mae: 0.0810
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - loss: 0.0100 - mae: 0.0693 - val_loss: 0.0114 - val_mae: 0.0715
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step - loss: 0.0094 - mae: 0.0661 - val_loss: 0.0116 - val_mae: 0.0733
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 166ms/step - loss: 0.0084 - mae: 0.0620 - val_loss: 0.0109 - val_mae: 0.0705
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - loss: 0.0079 - mae: 0.0603 - val_loss: 0.0107 - val_mae: 0.0692
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - loss: 0.0074 - mae: 0.0582 - val_loss: 0.0119 - val_mae: 0.0738
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - loss: 0.0087 - mae: 0.0637 - val_loss: 0.0113 - val_mae: 0.0733
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - loss: 0.0082 - mae: 0.0628 - val_loss: 0.0112 - val_mae: 0.0713
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 175ms/step - loss: 0.0086 - mae: 0.0642 - val_loss: 0.0105 - val_mae: 0.0673
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - loss: 0.0079 - mae: 0.0598 - val_loss: 0.0103 - val_mae: 0.0669

# %%
# Cell 5 (Updated): Evaluation Function
def evaluate_and_plot(model, lr_img, hr_img, title="Test Image"):
    sr_img = model.predict(lr_img[np.newaxis, ...])[0]
    
    # Convert to same dtype and ensure float32
    hr_img = hr_img.astype(np.float32)
    sr_img = sr_img.astype(np.float32)
    
    # Calculate metrics
    psnr_value = psnr(hr_img, sr_img, data_range=1.0)
    ssim_value = ssim(hr_img, sr_img, 
                     data_range=1.0,
                     channel_axis=2,  # Specify color channel axis
                     win_size=7)      # Minimum window size
    
    plt.figure(figsize=(15, 5))
    
    plt.subplot(1, 3, 1)
    plt.imshow(lr_img)
    plt.title('Low Resolution')
    plt.axis('off')
    
    plt.subplot(1, 3, 2)
    plt.imshow(hr_img)
    plt.title('Ground Truth')
    plt.axis('off')
    
    plt.subplot(1, 3, 3)
    plt.imshow(sr_img)
    plt.title(f'Super Resolved\nPSNR: {psnr_value:.2f}, SSIM: {ssim_value:.4f}')
    plt.axis('off')
    
    plt.suptitle(title)
    plt.tight_layout()
    plt.show()
    
    return psnr_value, ssim_value

# %%
# Cell 6: Evaluate Test Images
print("Evaluating test images...")
psnr_values = []
ssim_values = []

for i in range(min(5, len(lr_test))):
    psnr_val, ssim_val = evaluate_and_plot(
        model, lr_test[i], hr_test[i], 
        f"Test Image {i+1}"
    )
    psnr_values.append(psnr_val)
    ssim_values.append(ssim_val)

print(f"\nAverage PSNR: {np.mean(psnr_values):.2f} dB")
print(f"Average SSIM: {np.mean(ssim_values):.4f}")
# Out:
# Evaluating test images...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Average PSNR: 19.82 dB
# Average SSIM: 0.5494
